# %%
import os

output_folder = os.path.expanduser("~/Desktop/gcc-wef-nexus")
data_folder = os.path.expanduser("~/Desktop/gcc-wef-nexus/data")

print("✓ Ready")
print("✓ Output folder:", output_folder)
# Out:
# ✓ Ready
# ✓ Output folder: C:\Users\HP/Desktop/gcc-wef-nexus

# %%
# This cell generates your professional project summary
summary = """
=================================================================
   GCC WATER-ENERGY-FOOD NEXUS VULNERABILITY ANALYSIS
   Author: Dr. Adedamola Akeem Siyanbola (Ph.D)
   Date: May 2026
   Tools: Python | Pandas | Matplotlib | Seaborn | World Bank Data
=================================================================

RESEARCH QUESTION
-----------------
How vulnerable are the six GCC member states to Water-Energy-Food 
(WEF) Nexus shocks, and which countries face the most critical 
systemic risks as of 2023?

METHODOLOGY
-----------
1. Data sourced from World Bank World Development Indicators (2024)
   covering 6 indicators across 6 GCC countries from 2000 to 2023.
2. Indicators normalised to a 0-10 vulnerability scale using 
   Min-Max normalisation.
3. Composite WEF Index computed as weighted average:
   Water (35%) + Energy (35%) + Food (30%).
4. Country averages computed over 2018-2023 for stability.

KEY FINDINGS
------------
Rank 1 - Saudi Arabia  (WEF Index: 6.38) — Energy transition gap
Rank 2 - Bahrain       (WEF Index: 6.02) — Extreme water scarcity
Rank 3 - Kuwait        (WEF Index: 5.34) — Balanced vulnerability
Rank 4 - Oman          (WEF Index: 4.13) — Food import dependency
Rank 5 - Qatar         (WEF Index: 4.08) — Moderate across all
Rank 6 - UAE           (WEF Index: 2.39) — Least vulnerable

HEADLINE INSIGHTS
-----------------
1. Saudi Arabia's biggest vulnerability is NOT water — it is the 
   widest gap between renewable energy ambition and actual delivery
   in the entire GCC (energy score: 9.95/10).

2. Bahrain faces the most acute water crisis of any GCC member 
   (water score: 9.96/10), compounded by its status as a low-lying
   island exposed to sea-level rise.

3. UAE's early investment in nuclear (Barakah) and solar energy 
   is already measurably reducing its systemic vulnerability —
   the only GCC member with an energy score below 1.0.

4. Kuwait is the only GCC country with effectively zero renewable
   electricity output — confirmed by a renewable score of 0.00,
   making its energy transition the most urgent in the region.

5. Oman's relatively low overall vulnerability masks a critical 
   food security weakness (food score: 9.23) driven by high 
   import dependency and limited agricultural capacity.

POLICY RECOMMENDATIONS
----------------------
Saudi Arabia: Accelerate renewable deployment beyond Vision 2030 
targets — current trajectory is insufficient given energy score.

Bahrain: Prioritise solar-powered desalination to break the 
fossil fuel-water dependency spiral. Explore regional water 
cooperation framework with GCC neighbours.

Kuwait: Implement the 1.1 GW Shagaya solar project immediately —
zero renewable output is fiscally and environmentally unsustainable.

UAE: Share Barakah and solar financing model with GCC peers —
demonstrated success warrants regional knowledge transfer.

Oman: Leverage green hydrogen revenues to fund food security 
buffers and strategic food reserves.

Qatar: LNG expansion revenues should be ring-fenced partially 
for renewable transition — the only GCC member with no net-zero 
target represents a growing reputational and fiscal risk.

DATA SOURCES
------------
- World Bank World Development Indicators (2024)
  https://databank.worldbank.org/source/world-development-indicators
- Coverage: 2000-2023 | 6 countries | 6 indicators
- Analysis conducted in Python 3 using Pandas and Matplotlib

=================================================================
"""

print(summary)

# Save as a text file
output_folder = os.path.expanduser("~/Desktop/gcc-wef-nexus")
with open(os.path.join(output_folder, "PROJECT_SUMMARY.txt"), "w") as f:
    f.write(summary)

print("✓ Project summary saved as PROJECT_SUMMARY.txt")
# Out:
# ...
#    GCC WATER-ENERGY-FOOD NEXUS VULNERABILITY ANALYSIS
#    Author: Dr. Adedamola Akeem Siyanbola (Ph.D)
#    Date: May 2026
#    Tools: Python | Pandas | Matplotlib | Seaborn | World Bank Data
# ...
#
# RESEARCH QUESTION
# -----------------
# How vulnerable are the six GCC member states to Water-Energy-Food
# (WEF) Nexus shocks, and which countries face the most critical
# systemic risks as of 2023?
#
# METHODOLOGY
# -----------
# 1. Data sourced from World Bank World Development Indicators (2024)
#    covering 6 indicators across 6 GCC countries from 2000 to 2023.
# 2. Indicators normalised to a 0-10 vulnerability scale using
#    Min-Max normalisation.
# 3. Composite WEF Index computed as weighted average:
#    Water (35%) + Energy (35%) + Food (30%).
# 4. Country averages computed over 2018-2023 for stability.
#
# KEY FINDINGS
# ------------
# Rank 1 - Saudi Arabia  (WEF Index: 6.38) — Energy transition gap
# Rank 2 - Bahrain       (WEF Index: 6.02) — Extreme water scarcity
# ...

# %%
# This cell generates your professional project summary
summary = """
=================================================================
   GCC WATER-ENERGY-FOOD NEXUS VULNERABILITY ANALYSIS
   Author: Dr. Adedamola Akeem Siyanbola (Ph.D)
   Date: May 2026
   Tools: Python | Pandas | Matplotlib | Seaborn | World Bank Data
=================================================================

RESEARCH QUESTION
-----------------
How vulnerable are the six GCC member states to Water-Energy-Food 
(WEF) Nexus shocks, and which countries face the most critical 
systemic risks as of 2023?

METHODOLOGY
-----------
1. Data sourced from World Bank World Development Indicators (2024)
   covering 6 indicators across 6 GCC countries from 2000 to 2023.
2. Indicators normalised to a 0-10 vulnerability scale using 
   Min-Max normalisation.
3. Composite WEF Index computed as weighted average:
   Water (35%) + Energy (35%) + Food (30%).
4. Country averages computed over 2018-2023 for stability.

KEY FINDINGS
------------
Rank 1 - Saudi Arabia  (WEF Index: 6.38) — Energy transition gap
Rank 2 - Bahrain       (WEF Index: 6.02) — Extreme water scarcity
Rank 3 - Kuwait        (WEF Index: 5.34) — Balanced vulnerability
Rank 4 - Oman          (WEF Index: 4.13) — Food import dependency
Rank 5 - Qatar         (WEF Index: 4.08) — Moderate across all
Rank 6 - UAE           (WEF Index: 2.39) — Least vulnerable

HEADLINE INSIGHTS
-----------------
1. Saudi Arabia's biggest vulnerability is NOT water — it is the 
   widest gap between renewable energy ambition and actual delivery
   in the entire GCC (energy score: 9.95/10).

2. Bahrain faces the most acute water crisis of any GCC member 
   (water score: 9.96/10), compounded by its status as a low-lying
   island exposed to sea-level rise.

3. UAE's early investment in nuclear (Barakah) and solar energy 
   is already measurably reducing its systemic vulnerability —
   the only GCC member with an energy score below 1.0.

4. Kuwait is the only GCC country with effectively zero renewable
   electricity output — confirmed by a renewable score of 0.00,
   making its energy transition the most urgent in the region.

5. Oman's relatively low overall vulnerability masks a critical 
   food security weakness (food score: 9.23) driven by high 
   import dependency and limited agricultural capacity.

POLICY RECOMMENDATIONS
----------------------
Saudi Arabia: Accelerate renewable deployment beyond Vision 2030 
targets — current trajectory is insufficient given energy score.

Bahrain: Prioritise solar-powered desalination to break the 
fossil fuel-water dependency spiral. Explore regional water 
cooperation framework with GCC neighbours.

Kuwait: Implement the 1.1 GW Shagaya solar project immediately —
zero renewable output is fiscally and environmentally unsustainable.

UAE: Share Barakah and solar financing model with GCC peers —
demonstrated success warrants regional knowledge transfer.

Oman: Leverage green hydrogen revenues to fund food security 
buffers and strategic food reserves.

Qatar: LNG expansion revenues should be ring-fenced partially 
for renewable transition — the only GCC member with no net-zero 
target represents a growing reputational and fiscal risk.

DATA SOURCES
------------
- World Bank World Development Indicators (2024)
  https://databank.worldbank.org/source/world-development-indicators
- Coverage: 2000-2023 | 6 countries | 6 indicators
- Analysis conducted in Python 3 using Pandas and Matplotlib

=================================================================
"""

print(summary)

# Save as a text file
output_folder = os.path.expanduser("~/Desktop/gcc-wef-nexus")
with open(os.path.join(output_folder, "PROJECT_SUMMARY.txt"), "w") as f:
    f.write(summary)

print("✓ Project summary saved as PROJECT_SUMMARY.txt")
# Out:
# ...
#    GCC WATER-ENERGY-FOOD NEXUS VULNERABILITY ANALYSIS
#    Author: Dr. Adedamola Akeem Siyanbola (Ph.D)
#    Date: May 2026
#    Tools: Python | Pandas | Matplotlib | Seaborn | World Bank Data
# ...
#
# RESEARCH QUESTION
# -----------------
# How vulnerable are the six GCC member states to Water-Energy-Food
# (WEF) Nexus shocks, and which countries face the most critical
# systemic risks as of 2023?
#
# METHODOLOGY
# -----------
# 1. Data sourced from World Bank World Development Indicators (2024)
#    covering 6 indicators across 6 GCC countries from 2000 to 2023.
# 2. Indicators normalised to a 0-10 vulnerability scale using
#    Min-Max normalisation.
# 3. Composite WEF Index computed as weighted average:
#    Water (35%) + Energy (35%) + Food (30%).
# 4. Country averages computed over 2018-2023 for stability.
#
# KEY FINDINGS
# ------------
# Rank 1 - Saudi Arabia  (WEF Index: 6.38) — Energy transition gap
# Rank 2 - Bahrain       (WEF Index: 6.02) — Extreme water scarcity
# ...

# %%
readme = """# GCC Water-Energy-Food Nexus Vulnerability Analysis
**Author:** Dr. Adedamola Akeem Siyanbola (Ph.D) | May 2026  
**Tools:** Python · Pandas · Matplotlib · Seaborn · World Bank API  
**Data:** World Bank WDI (2000–2023) · 6 Countries · 6 Indicators

---

## Overview
This project constructs an original **Water-Energy-Food (WEF) Nexus 
Vulnerability Index** for all six Gulf Cooperation Council (GCC) member 
states — Saudi Arabia, UAE, Qatar, Oman, Kuwait, and Bahrain — using 
authoritative World Bank data covering 2000 to 2023.

The index reveals which GCC countries face the greatest systemic risk 
at the intersection of water scarcity, energy transition failure, and 
food import dependency.

---

## Key Finding
| Rank | Country | WEF Index | Primary Vulnerability |
|------|---------|-----------|----------------------|
| 1 | Saudi Arabia | 6.38 | Energy transition gap |
| 2 | Bahrain | 6.02 | Extreme water scarcity |
| 3 | Kuwait | 5.34 | Balanced across all three |
| 4 | Oman | 4.13 | Food import dependency |
| 5 | Qatar | 4.08 | Moderate across all |
| 6 | UAE | 2.39 | Least vulnerable |

---

## Project Structure
# Out:
#   Cell In[4], line 1
#     readme = """# GCC Water-Energy-Food Nexus Vulnerability Analysis
#              ^
# _IncompleteInputError: incomplete input

# %%
readme_lines = [
    "# GCC Water-Energy-Food Nexus Vulnerability Analysis\n",
    "**Author:** Dr. Adedamola Akeem Siyanbola (Ph.D) | May 2026\n",
    "**Tools:** Python · Pandas · Matplotlib · Seaborn · World Bank Data\n",
    "**Data:** World Bank WDI (2000-2023) · 6 Countries · 6 Indicators\n\n",
    "---\n\n",
    "## Overview\n",
    "This project constructs an original **Water-Energy-Food (WEF) Nexus Vulnerability Index** ",
    "for all six Gulf Cooperation Council (GCC) member states using World Bank data (2000-2023).\n\n",
    "---\n\n",
    "## Key Findings\n",
    "| Rank | Country | WEF Index | Primary Vulnerability |\n",
    "|------|---------|-----------|----------------------|\n",
    "| 1 | Saudi Arabia | 6.38 | Energy transition gap |\n",
    "| 2 | Bahrain | 6.02 | Extreme water scarcity |\n",
    "| 3 | Kuwait | 5.34 | Balanced across all three |\n",
    "| 4 | Oman | 4.13 | Food import dependency |\n",
    "| 5 | Qatar | 4.08 | Moderate across all |\n",
    "| 6 | UAE | 2.39 | Least vulnerable |\n\n",
    "---\n\n",
    "## Methodology\n",
    "1. **Data collection:** World Bank WDI via web portal (2024)\n",
    "2. **Normalisation:** Min-Max scaling to 0-10 vulnerability scale\n",
    "3. **Weighting:** Water 35% · Energy 35% · Food 30%\n",
    "4. **Period:** 2018-2023 average for index stability\n\n",
    "---\n\n",
    "## Project Structure\n",
    "- data/ — raw and cleaned datasets\n",
    "- charts/ — 5 publication-quality figures\n",
    "- 01_data_exploration.ipynb — data loading and cleaning\n",
    "- 02_wef_index.ipynb — index construction\n",
    "- 03_visualisations.ipynb — all 5 charts\n",
    "- 04_policy_memo.ipynb — findings and recommendations\n\n",
    "---\n\n",
    "## Headline Insights\n",
    "- Saudi Arabia's biggest vulnerability is energy transition failure, not water\n",
    "- Bahrain faces the GCC's most acute water crisis (score 9.96/10)\n",
    "- Kuwait has effectively zero renewable electricity output\n",
    "- UAE's early clean energy investment is measurably reducing systemic risk\n\n",
    "---\n\n",
    "## How to Run\n",
    "1. Clone this repository\n",
    "2. Open Jupyter Notebook\n",
    "3. Run notebooks in order: 01 then 02 then 03 then 04\n\n",
    "---\n\n",
    "## Author\n",
    "**Dr. Adedamola Akeem Siyanbola (Ph.D)**\n",
    "Senior Lecturer, Department of Economics\n",
    "Olabisi Onabanjo University, Nigeria\n",
    "Email: siyanbolaadedamola@gmail.com\n",
    "GitHub: github.com/DrSiyan1\n",
]

readme = "".join(readme_lines)

# Save the file
with open(os.path.join(output_folder, "README.md"), "w") as f:
    f.write(readme)

print("✓ README.md saved successfully!")
print("✓ Location:", output_folder)
# Out:
# ✓ README.md saved successfully!
# ✓ Location: C:\Users\HP/Desktop/gcc-wef-nexus
